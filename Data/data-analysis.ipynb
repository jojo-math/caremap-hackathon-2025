# %% [markdown]
# ## Fichier d'analyse des donnees sur les hopitaux de Douala et Yaounde

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
dialyse = pd.read_csv('CareMap_Dialyse.csv')
hospitaux = pd.read_csv('CareMap_Hopitaux.csv')
imagerie = pd.read_csv('CareMap_Imagerie.csv')
laboratoires = pd.read_csv('CareMap_Laboratoires.csv')
medecine_traditionnelle = pd.read_csv('CareMap_Medecine_Traditionnelle.csv')
ophtalmologie = pd.read_csv('CareMap_Ophtalmologie.csv')
pharmacies = pd.read_csv('CareMap_Pharmacies.csv')
reeducation_kine = pd.read_csv('CareMap_Reeducation_Kine.csv')
vaccination_pmi = pd.read_csv('CareMap_Vaccination_PMI.csv')
dialyse.head(1)
hospitaux.head(1)
imagerie.head(1)
laboratoires.head(1)
medecine_traditionnelle.head(1)
ophtalmologie.head(1)
pharmacies.head(1)
reeducation_kine.head(1)
vaccination_pmi.head(1)
# Out:
#         id               nom    ville arrondissement quartier  latitude  \
# 0  VAC0001  PMI Saint-Jeanne  Yaoundé      Yaoundé V    Nkomo  3.860847
#
#    longitude         telephone             email type_centre  \
# 0  11.514347  +237 693 362 565  jeanne@gmail.com         PMI
#
#   vaccination_enfants vaccination_adultes suivi_grossesse planning_familial  \
# 0                 Oui                 Oui             Non               Oui
#
#   consultation_nourrissons                                vaccins_disponibles  \
# 0                      Oui  Hépatite B | Tétanos | Méningite | DTP | BCG |...
#
#   carnet_sante_numerique             horaires
# 0                    Non  Lun–Sam 07h00–20h00

# %%
vaccination_pmi.isnull().sum()
# Out:
# id                          0
# nom                         0
# ville                       0
# arrondissement              0
# quartier                    0
# latitude                    0
# longitude                   0
# telephone                   0
# email                       0
# type_centre                 0
# vaccination_enfants         0
# vaccination_adultes         0
# suivi_grossesse             0
# planning_familial           0
# consultation_nourrissons    0
# vaccins_disponibles         0
# carnet_sante_numerique      0
# horaires                    0
# dtype: int64
