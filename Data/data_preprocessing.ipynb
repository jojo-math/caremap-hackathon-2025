# %%
#1- IMPORTER LES LIBRAIRIES
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('CareMap_Dialyse.csv')
data1=pd.read_csv('CareMap_Hopitaux.csv')
data2=pd.read_csv('CareMap_Imagerie.csv')
data3=pd.read_csv('CareMap_Laboratoires.csv')
data4=pd.read_csv('CareMap_Medecine_Traditionnelle.csv')
data5=pd.read_csv('CareMap_Ophtalmologie.csv')
data6=pd.read_csv('CareMap_Pharmacies.csv')
data7=pd.read_csv('CareMap_Reeducation_Kine.csv')
data8=pd.read_csv('CareMap_Vaccination_PMI.csv')

# %%
data.head()
data1.head()
data2.head()
data3.head()
data4.head()
data5.head()
data6.head()
data7.head()
data8.head()
# Out:
#         id                                              nom    ville  \
# 0  VAC0001                                 PMI Saint-Jeanne  Yaoundé
# 1  VAC0002                                      PMI de PK14   Douala
# 2  VAC0003                      Centre de Vaccination Salut  Yaoundé
# 3  VAC0004  Centre de Santé Maternelle et Infantile de Bali   Douala
# 4  VAC0005                             PMI Saint-Bernadette  Yaoundé
#
#   arrondissement   quartier  latitude  longitude         telephone  \
# 0      Yaoundé V      Nkomo  3.860847  11.514347  +237 693 362 565
# 1       Douala V       PK14  4.004687   9.681276  +237 696 285 252
# 2      Yaoundé I    Ngousso  3.953071  11.528054  +237 243 134 688
# 3      Douala II    Ndoghem  3.976428   9.670393  +237 233 675 878
# 4    Yaoundé III  Étoa-Meki  3.835409  11.539554  +237 677 601 309
#
#                      email            type_centre vaccination_enfants  \
# 0         jeanne@gmail.com                    PMI                 Oui
# ...

# %%
data.isna().sum()
# Out:
# id                          0
# nom                         0
# ville                       0
# arrondissement              0
# quartier                    0
# latitude                    0
# longitude                   0
# telephone                   0
# email                       0
# hemodialyse                 0
# dialyse_peritoneale         0
# nb_postes_dialyse           0
# seances_par_semaine         0
# consultation_nephrologue    0
# urgences_renales            0
# prise_en_charge_cnps        0
# prise_en_charge_minsante    0
# horaires                    0
# dtype: int64

# %%
data1.isna().sum()
# Out:
# id                 0
# nom                0
# ville              0
# arrondissement     0
# quartier           0
# latitude           0
# longitude          0
# telephone          0
# email              0
# type_hopital       0
# couveuses          0
# bloc_operatoire    0
# urgences_24h       0
# maternite          0
# dtype: int64

# %%
data2.isna().sum()
# Out:
# id                0
# nom               0
# ville             0
# arrondissement    0
# quartier          0
# latitude          0
# longitude         0
# telephone         0
# email             0
# radiographie      0
# echographie       0
# scanner           0
# irm               0
# mammographie      0
# doppler           0
# horaires          0
# dtype: int64

# %%
data3.isna().sum()
# Out:
# id                      0
# nom                     0
# ville                   0
# arrondissement          0
# quartier                0
# latitude                0
# longitude               0
# telephone               0
# email                   0
# analyses_courantes      0
# bilan_complet           0
# bacteriologie           0
# serologie               0
# pcr_covid_paludisme     0
# prelevement_domicile    0
# resultat_en_ligne       0
# horaires                0
# dtype: int64

# %%
data4.isna().sum()
# Out:
# id                         0
# nom                        0
# ville                      0
# arrondissement             0
# quartier                   0
# latitude                   0
# longitude                  0
# telephone                  0
# email                      0
# agree_minsante             0
# phytotherapie              0
# acupuncture                0
# massage_therapeutique      0
# traitement_paludisme       0
# traitement_diabete         0
# traitement_hypertension    0
# plante_principale          0
# horaires                   0
# dtype: int64

# %%
data5.isna().sum()
# Out:
# id                       0
# nom                      0
# ville                    0
# arrondissement           0
# quartier                 0
# latitude                 0
# longitude                0
# telephone                0
# email                    0
# consultation_generale    0
# chirurgie_oculaire       0
# correction_visuelle      0
# vente_lunettes           0
# traitement_cataracte     0
# traitement_glaucome      0
# laser_vision             0
# horaires                 0
# dtype: int64

# %%
data6.isna().sum()
# Out:
# id                    0
# nom                   0
# ville                 0
# arrondissement        0
# quartier              0
# latitude              0
# longitude             0
# telephone             0
# email                 0
# pharmacie_de_garde    0
# type_garde            0
# horaires              0
# livraison_domicile    0
# parapharmacie         0
# materiel_medical      0
# dtype: int64

# %%
data7.isna().sum()
# Out:
# id                           0
# nom                          0
# ville                        0
# arrondissement               0
# quartier                     0
# latitude                     0
# longitude                    0
# telephone                    0
# email                        0
# kinesitherapie               0
# reeducation_post_op          0
# reeducation_neurologique     0
# reeducation_pediatrique      0
# osteopathie                  0
# appareillage_orthopedique    0
# seances_domicile             0
# horaires                     0
# dtype: int64

# %%
data8.isna().sum()
# Out:
# id                          0
# nom                         0
# ville                       0
# arrondissement              0
# quartier                    0
# latitude                    0
# longitude                   0
# telephone                   0
# email                       0
# type_centre                 0
# vaccination_enfants         0
# vaccination_adultes         0
# suivi_grossesse             0
# planning_familial           0
# consultation_nourrissons    0
# vaccins_disponibles         0
# carnet_sante_numerique      0
# horaires                    0
# dtype: int64

# %%
data.head()
# Out:
#         id                               nom    ville arrondissement  \
# 0  DIA0001                 Centre Rénal Nkoa  Yaoundé     Yaoundé II
# 1  DIA0002    Centre de Dialyse Saint-Cécile   Douala       Douala V
# 2  DIA0003                   Dialyse Lumière   Douala      Douala II
# 3  DIA0004    Centre de Dialyse de Étoa-Meki  Yaoundé     Yaoundé II
# 4  DIA0005  Centre de Dialyse de Briqueterie  Yaoundé    Yaoundé III
#
#       quartier  latitude  longitude         telephone                  email  \
# 0     Nlongkak  3.779823  11.515455  +237 650 140 896  rénalnkoa@hotmail.com
# 1         Bali  4.065117   9.734426  +237 677 121 725     cécile@hotmail.com
# 2    Bonapriso  3.990417   9.720575  +237 233 785 017       lumière@yahoo.fr
# 3         Nsam  3.789256  11.556651  +237 691 626 972     étoa-meki@yahoo.fr
# 4  Briqueterie  3.933926  11.495180  +237 678 070 395   briqueterie@yahoo.fr
#
#   hemodialyse dialyse_peritoneale  nb_postes_dialyse seances_par_semaine  \
# ...

# %%
sns.heatmap(data.select_dtypes(include=["number"]).corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(data1.select_dtypes(include=["number"]).corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(data3.select_dtypes(include=["number"]).corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(data4.select_dtypes(include=["number"]).corr(),annot=True)
# Out:
# <Axes: >

# %%
data.duplicated().value_counts()
data.shape
# Out:
# (350, 18)

# %%
data1.duplicated().value_counts()
data1.shape
# Out:
# (700, 14)

# %%
# Pourcentage de lignes dupliquées
taux_doublons = data2.duplicated().sum() / len(data2) * 100
print(f"Taux de doublons : {taux_doublons:.2f}%")
# Out:
# Taux de doublons : 0.00%

# %%
# Pourcentage de lignes dupliquées
taux_doublons = data1.duplicated().sum() / len(data1) * 100
print(f"Taux de doublons : {taux_doublons:.2f}%")
# Out:
# Taux de doublons : 0.00%

# %%
# Pourcentage de lignes dupliquées
taux_doublons = data3.duplicated().sum() / len(data3) * 100
print(f"Taux de doublons : {taux_doublons:.2f}%")
# Out:
# Taux de doublons : 0.00%

# %%
# Pourcentage de lignes dupliquées
taux_doublons = data4.duplicated().sum() / len(data4) * 100
print(f"Taux de doublons : {taux_doublons:.2f}%")
# Out:
# Taux de doublons : 0.00%

# %%
# Pourcentage de lignes dupliquées
taux_doublons = data5.duplicated().sum() / len(data5) * 100
print(f"Taux de doublons : {taux_doublons:.2f}%")
# Out:
# Taux de doublons : 0.00%

# %%
# Pourcentage de lignes dupliquées
taux_doublons = data6.duplicated().sum() / len(data6) * 100
print(f"Taux de doublons : {taux_doublons:.2f}%")
# Out:
# Taux de doublons : 0.00%

# %%
# Pourcentage de lignes dupliquées
taux_doublons = data7.duplicated().sum() / len(data7) * 100
print(f"Taux de doublons : {taux_doublons:.2f}%")
# Out:
# Taux de doublons : 0.00%

# %%
# Pourcentage de lignes dupliquées
taux_doublons = data8.duplicated().sum() / len(data8) * 100
print(f"Taux de doublons : {taux_doublons:.2f}%")
# Out:
# Taux de doublons : 0.00%

# %%
# Distribution par ville (pour chaque fichier)
print(data['ville'].value_counts())
print(data1['ville'].value_counts())

# Top quartiers avec le plus de structures
all_quartiers = pd.concat([data['quartier'], data1['quartier']])
print(all_quartiers.value_counts().head(10))
# Out:
# ville
# Yaoundé    175
# Douala     175
# Name: count, dtype: int64
# ville
# Yaoundé    350
# Douala     350
# Name: count, dtype: int64
# quartier
# Ndogbong             18
# Ngousso              18
# PK14                 17
# Bepanda              17
# Mvog-Atangana        17
# Deido                17
# Cité des Palmiers    16
# Sodiko               16
# Kotto                16
# Youpwé               16
# Name: count, dtype: int64

# %% [markdown]
# - Interprétation : Les données sont artificiellement équilibrées (50/50 entre Yaoundé et Douala). Cela confirme la mention du brief : "Les données sont entièrement fictives". Dans la réalité, la répartition ne serait pas aussi parfaite.
# - Interprétation :
#     Ndogbong et Ngousso sont les quartiers les mieux dotés (18 structures chacun)
#     Les quartiers populaires comme Bepanda, Deido, PK14 (Douala) sont bien représentés
#     Mvog-Atangana, Kotto, Youpwé (Yaoundé) concentrent aussi beaucoup de structures

# %% [markdown]
# À mentionner dans le pitch : "Notre jeu de données, bien que fictif, simule une couverture sanitaire équivalente entre Yaoundé et Douala"

# %% [markdown]
# # Pour le Speech
# Notre analyse montre une répartition équilibrée entre Yaoundé et Douala, avec des zones de forte concentration sanitaire comme Ndogbong et Ngousso. Cela garantit une expérience utilisateur homogène sur les deux villes.
